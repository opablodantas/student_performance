# %% [markdown]
# # Student Performance Data Set

# %% [markdown]
# This data approach student achievement in secondary education of two Portuguese schools. The data attributes include student grades, demographic, social and school related features) and it was collected by using school reports and questionnaires. Two datasets are provided regarding the performance in two distinct subjects: Mathematics (mat) and Portuguese language (por). In [Cortez and Silva, 2008], the two datasets were modeled under binary/five-level classification and regression tasks. Important note: the target attribute G3 has a strong correlation with attributes G2 and G1. This occurs because G3 is the final year grade (issued at the 3rd period), while G1 and G2 correspond to the 1st and 2nd period grades. It is more difficult to predict G3 without G2 and G1, but such prediction is much more useful
#
# Estes dados abordam o aproveitamento dos alunos do ensino secundário de duas escolas portuguesas. Os atributos de dados incluem notas dos alunos, características demográficas, sociais e escolares) e foram coletados por meio de relatórios e questionários escolares. São fornecidos dois conjuntos de dados relativos ao desempenho em duas disciplinas distintas: Matemática (esteira) e Língua Portuguesa (por). Em [Cortez e Silva, 2008], os dois conjuntos de dados foram modelados sob classificação binária / cinco níveis e tarefas de regressão. Nota importante: o atributo alvo G3 tem forte correlação com os atributos G2 e G1. Isso ocorre porque G3 é a nota do último ano (emitida no 3º período), enquanto G1 e G2 correspondem às notas do 1º e 2º períodos. É mais difícil prever G3 sem G2 e G1, mas essa previsão é muito mais útil
#
# More information: https://archive.ics.uci.edu/ml/datasets/student+performance

# %% [markdown]
# ## Descrição dos dados
#
#  Attributes for both student-mat.csv (Math course) and student-por.csv (Portuguese language course) datasets:
#
#
# - 1 school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
#
# - 2 sex - student's sex (binary: 'F' - female or 'M' - male)
#
# - 3 age - student's age (numeric: from 15 to 22)
#
# - 4 address - student's home address type (binary: 'U' - urban or 'R' - rural)
#
# - 5 famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
#
# - 6 Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
#
# - 7 Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 - 5th to 9th grade, 3 - secondary
# education or 4 - higher education)
#
# - 8 Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 -5th to 9th grade, 3 - secondary
# education or 4 - higher education)
#
# - 9 Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#
# - 10 Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#
# - 11 reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
#
# - 12 guardian - student's guardian (nominal: 'mother', 'father' or 'other')
#
# - 13 traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
#
# - 14 studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
#
# - 15 failures - number of past class failures (numeric: n if 1<=n<3, else 4)
#
# - 16 schoolsup - extra educational support (binary: yes or no)
#
# - 17 famsup - family educational support (binary: yes or no)
#
# - 18 paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
#
# - 19 activities - extra-curricular activities (binary: yes or no)
#
# - 20 nursery - attended nursery school (binary: yes or no)
#
# - 21 higher - wants to take higher education (binary: yes or no)
#
# - 22 internet - Internet access at home (binary: yes or no)
#
# - 23 romantic - with a romantic relationship (binary: yes or no)
#
# - 24 famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
#
# - 25 freetime - free time after school (numeric: from 1 - very low to 5 - very high)
#
# - 26 goout - going out with friends (numeric: from 1 - very low to 5 - very high)
#
# - 27 Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# - 28 Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# - 29 health - current health status (numeric: from 1 - very bad to 5 - very good)
#
# - 30 absences - number of school absences (numeric: from 0 to 93)
#
# These grades are related with the course subject, Math or Portuguese:
#
# - 31 G1 - first period grade (numeric: from 0 to 20)
#
# - 31 G2 - second period grade (numeric: from 0 to 20)
#
# - 32 G3 - final grade (numeric: from 0 to 20, output target)

# %% [markdown]
# ## Leitura de dados com pandas

# %%
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings('ignore')

# %%
mat = pd.read_csv('student-mat.csv', sep = ';')
port = pd.read_csv('student-por.csv', sep = ';')

# %%
mat['subject'] = 'mat'
port['subject'] = 'port'

# %%
df = pd.concat([mat, port])

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
df.shape
# Out:
# (1044, 34)

# %% [markdown]
# ## Manipulação e limpeza de dados com pandas

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# subject       0
# dtype: int64

# %%
df.nunique()
# Felizmente não há grande variedade nas colunas
# Out:
# school         2
# sex            2
# age            8
# address        2
# famsize        2
# Pstatus        2
# Medu           5
# Fedu           5
# Mjob           5
# Fjob           5
# reason         4
# guardian       3
# traveltime     4
# studytime      4
# failures       4
# schoolsup      2
# famsup         2
# paid           2
# activities     2
# nursery        2
# higher         2
# internet       2
# romantic       2
# famrel         5
# freetime       5
# goout          5
# Dalc           5
# Walc           5
# health         5
# absences      35
# G1            18
# G2            17
# G3            19
# subject        2
# dtype: int64

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# subject       object
# dtype: object

# %%
df.describe()
# Out:
#                age         Medu         Fedu   traveltime    studytime  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean     16.726054     2.603448     2.387931     1.522989     1.970307
# std       1.239975     1.124907     1.099938     0.731727     0.834353
# min      15.000000     0.000000     0.000000     1.000000     1.000000
# 25%      16.000000     2.000000     1.000000     1.000000     1.000000
# 50%      17.000000     3.000000     2.000000     1.000000     2.000000
# 75%      18.000000     4.000000     3.000000     2.000000     2.000000
# max      22.000000     4.000000     4.000000     4.000000     4.000000
#
#           failures       famrel     freetime        goout         Dalc  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      0.264368     3.935824     3.201149     3.156130     1.494253
# std       0.656142     0.933401     1.031507     1.152575     0.911714
# ...

# %% [markdown]
# ## Descritivo e exploração de dados

# %%
school_sexo = df.groupby([df.school, df.sex]).mean()[['G1','G2','G3']]
school_sexo
# Out:
#                    G1         G2         G3
# school sex
# GP     F    11.542857  11.585714  11.683333
#        M    11.477273  11.460227  11.573864
# MS     F    10.631579  10.660819  10.871345
#        M     9.910891  10.079208   9.910891

# %%
pd.crosstab(df['school'], df['sex']).describe()
# Out:
# sex             F           M
# count    2.000000    2.000000
# mean   295.500000  226.500000
# std    176.069589  177.483802
# min    171.000000  101.000000
# 25%    233.250000  163.750000
# 50%    295.500000  226.500000
# 75%    357.750000  289.250000
# max    420.000000  352.000000

# %% [markdown]
# ## Figuras que mostrem insights sobre os dados

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, ax = plt.subplots(3,3, figsize = (10,10))

ax[0][0].tick_params(labelrotation= 25)
sns.countplot(df.school, ax = ax[0][0])

ax[0][1].tick_params(labelrotation= 25)
sns.countplot(df.sex, ax = ax[0][1])

ax[0][2].tick_params(labelrotation= 25)
sns.countplot(df.address, ax = ax[0][2])

ax[1][0].tick_params(labelrotation= 25)
sns.countplot(df.famsize, ax = ax[1][0])

ax[1][1].tick_params(labelrotation= 25)
sns.countplot(df.Pstatus, ax = ax[1][1])

ax[1][2].tick_params(labelrotation= 25)
sns.countplot(df.Mjob, ax = ax[1][2])

ax[2][0].tick_params(labelrotation= 25)
sns.countplot(df.Fjob, ax = ax[2][0])

ax[2][1].tick_params(labelrotation= 25)
sns.countplot(df.reason, ax = ax[2][1])

ax[2][2].tick_params(labelrotation= 25)
sns.countplot(df.guardian, ax = ax[2][2])
              
fig.tight_layout(pad = 1.2)

# %% [markdown]
# #### Observações:
# - Gabriel Pereira é a escola que mais contem alunos registrados nesse conjunto de dados
# - De todos os alunos a maioria é do genero feminino,
# - A minoria mora na parte rural da cidade
# - Os alunos tambem possuem uma familia que obtem mais de tres pessoas em casa, e morando juntos,
# - Perceba que os trabalhos de ambos os pais em sua maioria está relacionado a categorias 'outros'
# - Veja que é declarado que a principal razao para escolher uma das escolas é a preferência pelo 'curso'
# - A guarda dos estudantes fica com a mae em sua maioria

# %%
plt.figure(figsize=(12,6))
plt.title('Tempo de Viajem de Casa para a Escola')
plt.xlabel('Tempo de viajem')
plt.ylabel('Porcentagem (%)')

ax = (df['traveltime'].value_counts()/len(df)*100).sort_index().plot(kind="bar", rot=0)
ax.set_yticks(np.arange(0, 110, 10))

ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(df)/100)

for p in ax.patches:
    ax.annotate('{:.2f}%'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+1))

# %% [markdown]
# Podemos observar que praticamente 60% dos estudantes demoram menos de 15 minutos

# %%
plt.figure(figsize=(12,6))
plt.title('Quantidade de Tempo de Estudo Semanalmente')
plt.xlabel('Tempo de Estudo')
plt.ylabel('Porcentagem (%)')

ax = (df['studytime'].value_counts()/len(df)*100).sort_index().plot(kind="bar", rot=0)
ax.set_yticks(np.arange(0, 110, 10))

ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(df)/100)

for p in ax.patches:
    ax.annotate('{:.2f}%'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+1))

# %% [markdown]
# É visto que praticamente metade dos alunos estudam cerca de 2 a 5 horas por semana

# %%
plt.figure(figsize=(12,6))
plt.title('')
plt.xlabel('')
plt.ylabel('Porcentagem (%)')

ax = (df['failures'].value_counts()/len(df)*100).sort_index().plot(kind="bar", rot=0)
ax.set_yticks(np.arange(0, 110, 10))

ax2 = ax.twinx()
ax2.set_yticks(np.arange(0, 110, 10)*len(df)/100)

for p in ax.patches:
    ax.annotate('{:.2f}%'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+1))

# %% [markdown]
# E sem surpresa, vemos que muitos alunos nunca reprovaram, mas 18% reprovaram ao menos uma vez, o que é um número impressionante

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# subject       object
# dtype: object

# %%
fig, ax = plt.subplots(2,4, figsize = (12,6))

ax[0][0].tick_params(labelrotation= 25)
sns.countplot(df.schoolsup, ax = ax[0][0])

ax[0][1].tick_params(labelrotation= 25)
sns.countplot(df.famsup, ax = ax[0][1])

ax[0][2].tick_params(labelrotation= 25)
sns.countplot(df.paid, ax = ax[0][2])

ax[0][3].tick_params(labelrotation= 25)
sns.countplot(df.activities, ax = ax[0][3])

ax[1][0].tick_params(labelrotation= 25)
sns.countplot(df.nursery, ax = ax[1][0])

ax[1][2].tick_params(labelrotation= 25)
sns.countplot(df.higher, ax = ax[1][1])

ax[1][3].tick_params(labelrotation= 25)
sns.countplot(df.internet, ax = ax[1][2])

ax[1][1].tick_params(labelrotation= 25)
sns.countplot(df.romantic, ax = ax[1][3])
              
fig.tight_layout(pad = 1.2)

# %% [markdown]
# #### Observações
# - Mais de 70% dos alunos não tem apoio educacional extra
# - Cerca de 60% dos estudantes possuem algum apoio educacional familiar
# - Pouquissimos alunos pagam por aulas extra no curso
# - Das atividades extra-curriculares, praticamente metade fazem e a outra metade não faz
# - Uma quantidade considerável não foi a creche quando mais jovem
# - Meno de 20% dos alunos não tem intenção de fazer o ensino superior
# - Felizmente a maioria tem acesso a internet
# - Como era de se esperar, a minoria tem alguma relação romantica

# %%
fig, ax = plt.subplots(2,3, figsize = (12,6))

ax[0][0].tick_params(labelrotation= 25)
sns.countplot(df.famrel, ax = ax[0][0])

ax[0][1].tick_params(labelrotation= 25)
sns.countplot(df.freetime, ax = ax[0][1])

ax[0][2].tick_params(labelrotation= 25)
sns.countplot(df.goout, ax = ax[0][2])

ax[1][0].tick_params(labelrotation= 25)
sns.countplot(df.Dalc, ax = ax[1][0])

ax[1][1].tick_params(labelrotation= 25)
sns.countplot(df.Walc, ax = ax[1][1])

ax[1][2].tick_params(labelrotation= 25)
sns.countplot(df.health, ax = ax[1][2])

fig.tight_layout(pad = 1.2)

# %% [markdown]
# - Felizmente a enorme maioria dos alunos tem uma relação boa ou excelente com seus familiares
# - O tempo livre após a escola é moderado pra cima
# - Sair com os amigos é moderado também
# - O consumo de alcool nos dias de semana é muito baixo e nos finais de semana, idem
# - A maioria dos alunos consideram sua saúde muito boa mas uma quantidade considerável a consideram muito ruim, é bom investigar

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %% [markdown]
# ## Quebrar os dados em conjunto de treino e conjunto de teste

# %%
from sklearn.model_selection import train_test_split

# %%
# Definindo X e y
X
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-344c8fb4cbde> in <module>
#       1 # Definindo X e y
# ----> 2 X
#       3 y
#
# NameError: name 'X' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# ## Treinar um estimador

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()

# %% [markdown]
# ## Verificar o desempenho do estimador
